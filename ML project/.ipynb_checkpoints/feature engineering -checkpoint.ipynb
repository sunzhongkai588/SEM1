# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import nan as NA
from sklearn.preprocessing import OneHotEncoder
from category_encoders import OrdinalEncoder

# %%
train_data =  pd.read_csv("train.csv")
#替换缺失值"？"为NA
train_data.replace(' ?', NA, inplace = True)
#返回有nan的列
train_data.isna().any()
#替换NAN的值为Unknown
train_data['workclass'].replace(NA, 'Unknown', inplace = True)
train_data['occupation'].replace(NA, 'Unknown', inplace = True)
train_data['native-country'].replace(NA, 'Unknown', inplace = True)


#国家数据重分类,分为发达国家和发展中国家（不要运行2次）
#由于美国人最多，所以将国家缺失值填补为US
train_data['native-country'].replace(' United-States', 'US', inplace = True)
train_data['native-country'].replace('Unknown', 'US', inplace = True)
country = train_data['native-country']
country_type = country.unique()
for native_country in country_type:
    if native_country in [' United States',' United Kingdom',' Germany',' France',' Japan',' Italy',' Canada',' Russia']:
        train_data['native-country'].replace(native_country, 'Developed_country', inplace = True)
    else:
        train_data['native-country'].replace(native_country, 'Uneveloped_country', inplace = True)




#     if native_country != ' United-States' and native_country != 'Unknown':
#         train_data['native-country'].replace(native_country, 'Non_US', inplace = True)

# %%
sns.barplot(x='native-country',y='exceeds50K',data=train_data)
# sns.countplot(x='native-country',hue='exceeds50K',data=train_data)
# Out:
# <AxesSubplot:xlabel='native-country', ylabel='exceeds50K'>

# %%
#按学历，将1为没上过学，2-8为没上过大学，9为高中文凭，10为大学未毕业（可视为高中），11-12为专科，因此，应该重分类
def education(education_num):
    if education_num == 1:
        return 0
    elif (education_num > 1) & (education_num < 9):
        return 1
    elif (education_num >= 9) & (education_num < 11):
        return 2
    elif (education_num >= 11) & (education_num < 13):
        return 3
    else:
        return (education_num-9)
train_data['education-num'] = train_data['education-num'].map(education)

# %%
#只能运行一次
#将每周工作时长分为三段，一段为小于每周40小时，一段为每周40小时，一段为每周大于40小时
def workhours(hours_per_week):
    if hours_per_week < 40:
        return 0
    elif hours_per_week == 40:
        return 1
    else:
        return 2
train_data['hours-per-week'] = train_data['hours-per-week'].map(workhours)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24421 entries, 0 to 24420
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             24421 non-null  int64
#  1   workclass       24421 non-null  object
#  2   fnlwgt          24421 non-null  int64
#  3   education       24421 non-null  object
#  4   education-num   24421 non-null  int64
#  5   marital-status  24421 non-null  object
#  6   occupation      24421 non-null  object
#  7   relationship    24421 non-null  object
#  8   sex             24421 non-null  object
#  9   capital-gain    24421 non-null  int64
#  10  capital-loss    24421 non-null  int64
#  11  hours-per-week  24421 non-null  int64
#  12  native-country  24421 non-null  object
#  13  exceeds50K      24421 non-null  int64
# dtypes: int64(7), object(7)
# memory usage: 2.6+ MB

# %%
#性别编码
encoder1 = OrdinalEncoder(cols = ['sex']).fit(train_data,train_data.iloc[:,-1]) # 转换sex为 female为1 和 male为2
train_data = encoder1.transform(train_data)
#国家编码
encoder2 = OrdinalEncoder(cols = ['native-country']).fit(train_data,train_data.iloc[:,-1]) # 转换sex为 female为1 和 male为2
train_data = encoder2.transform(train_data)
# Out:
# /Users/zachary-sun/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
train_data.head(50)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    30            Unknown  147215   Some-college              2
# 1    60            Private  173960      Bachelors              4
# 2    52            Unknown  105428   Some-college              2
# 3    37            Private  112497      Bachelors              4
# 4    63            Private  137843   Some-college              2
# 5    23          State-gov   82067      Assoc-voc              3
# 6    47       Self-emp-inc  212120        HS-grad              2
# 7    48   Self-emp-not-inc  171986        HS-grad              2
# 8    24            Private  180060     Assoc-acdm              3
# 9    25   Self-emp-not-inc  159909      Assoc-voc              3
# 10   59            Private  108496        Masters              5
# 11   60            Private  178050        HS-grad              2
# 12   22            Private  188544      Assoc-voc              3
# 13   47            Private  133758        HS-grad              2
# 14   33            Private   59944        HS-grad              2
# 15   65          Local-gov  153890           12th              1
# 16   40            Private  266084   Some-college              2
# 17   38          State-gov  108293        Masters              5
# 18   52            Private  139176        HS-grad              2
# 19   27          State-gov  205499      Doctorate              7
# 20   40       Self-emp-inc   64885        Masters              5
# 21   37            Private   19899        HS-grad              2
# 22   17            Private  263746           10th              1
# 23   24            Private  204226        Masters              5
# 24   55            Private  153484        Masters              5
# 25   56            Private  183169        HS-grad              2
# 26   48            Private  128460        HS-grad              2
# 27   35            Private  166606   Some-college              2
# 28   38            Private   65624        HS-grad              2
# 29   59            Private  279636        HS-grad              2
# 30   22            Private  254547   Some-college              2
# 31   55            Private  178353            9th              1
# 32   55            Private  158702   Some-college              2
# 33   17            Private  160049           10th              1
# 34   42            Private  219155      Bachelors              4
# 35   33   Self-emp-not-inc  134737        HS-grad              2
# 36   52            Private  177942        HS-grad              2
# 37   42            Private   44402      Bachelors              4
# 38   23            Private  203182      Bachelors              4
# 39   40            Private  168294        HS-grad              2
# 40   40            Private  232820      Assoc-voc              3
# 41   34            Private  193344   Some-college              2
# 42   24            Private  179203           12th              1
# 43   25          State-gov  157028      Bachelors              4
# 44   57       Self-emp-inc  220789        HS-grad              2
# 45   59            Private  142182        HS-grad              2
# 46   37       Self-emp-inc  163998     Assoc-acdm              3
# 47   18            Unknown  128538   Some-college              2
# 48   37          Local-gov  189878   Some-college              2
# 49   33       Self-emp-inc  374905        HS-grad              2
#
#          marital-status          occupation     relationship  sex  \
# 0         Never-married             Unknown        Own-child    1
# 1              Divorced      Prof-specialty    Not-in-family    1
# 2    Married-civ-spouse             Unknown          Husband    2
# 3    Married-civ-spouse               Sales          Husband    2
# 4    Married-civ-spouse               Sales          Husband    2
# 5    Married-civ-spouse     Protective-serv          Husband    2
# 6    Married-civ-spouse        Craft-repair          Husband    2
# 7              Divorced      Prof-specialty    Not-in-family    2
# 8         Never-married        Craft-repair    Not-in-family    2
# 9    Married-civ-spouse     Farming-fishing          Husband    2
# 10   Married-civ-spouse     Exec-managerial          Husband    2
# 11             Divorced       Other-service        Unmarried    1
# 12        Never-married        Adm-clerical        Own-child    1
# 13             Divorced     Exec-managerial    Not-in-family    1
# 14        Never-married    Transport-moving    Not-in-family    2
# 15              Widowed     Exec-managerial    Not-in-family    2
# 16             Divorced        Craft-repair   Other-relative    2
# 17        Never-married      Prof-specialty   Other-relative    1
# 18   Married-civ-spouse               Sales          Husband    2
# 19        Never-married      Prof-specialty    Not-in-family    2
# 20   Married-civ-spouse               Sales          Husband    2
# 21   Married-civ-spouse        Craft-repair          Husband    2
# 22        Never-married       Other-service        Own-child    2
# 23        Never-married      Prof-specialty    Not-in-family    1
# 24   Married-civ-spouse     Exec-managerial          Husband    2
# 25        Never-married        Adm-clerical        Own-child    1
# 26   Married-civ-spouse        Craft-repair          Husband    2
# 27   Married-civ-spouse     Exec-managerial          Husband    2
# 28             Divorced     Exec-managerial    Not-in-family    2
# 29        Never-married        Adm-clerical    Not-in-family    2
# 30        Never-married     Exec-managerial        Unmarried    1
# 31             Divorced   Machine-op-inspct    Not-in-family    2
# 32        Never-married        Adm-clerical    Not-in-family    1
# 33        Never-married       Other-service        Own-child    1
# 34   Married-civ-spouse               Sales          Husband    2
# 35   Married-civ-spouse        Craft-repair          Husband    2
# 36   Married-civ-spouse        Adm-clerical             Wife    1
# 37   Married-civ-spouse               Sales          Husband    2
# 38        Never-married               Sales    Not-in-family    1
# 39   Married-civ-spouse        Craft-repair          Husband    2
# 40             Divorced     Exec-managerial        Unmarried    1
# 41        Never-married        Adm-clerical        Unmarried    1
# 42        Never-married               Sales   Other-relative    2
# 43        Never-married     Exec-managerial    Not-in-family    2
# 44   Married-civ-spouse               Sales          Husband    2
# 45   Married-civ-spouse       Other-service          Husband    2
# 46   Married-civ-spouse               Sales          Husband    2
# 47        Never-married             Unknown        Own-child    1
# 48   Married-civ-spouse     Protective-serv          Husband    2
# 49   Married-civ-spouse               Sales          Husband    2
#
#     capital-gain  capital-loss  hours-per-week  native-country  exceeds50K
# 0              0             0               0               1           0
# 1              0             0               2               1           0
# 2              0             0               0               1           0
# 3              0             0               2               1           0
# 4           7298             0               2               1           1
# 5              0             0               1               1           0
# 6              0             0               1               1           1
# 7              0             0               0               1           0
# 8           2354             0               1               1           0
# 9              0             0               1               1           0
# 10             0             0               2               1           1
# 11             0             0               0               1           0
# 12             0             0               0               1           0
# 13             0          1974               1               1           0
# 14             0             0               1               1           0
# 15          2009             0               2               1           0
# 16             0             0               2               1           0
# 17             0             0               1               1           0
# 18             0             0               0               1           0
# 19             0             0               2               1           0
# 20             0             0               2               1           1
# 21         15024             0               2               1           1
# 22             0             0               0               1           0
# 23             0             0               1               1           0
# 24             0          1977               2               1           1
# 25             0             0               0               1           0
# 26             0             0               2               1           1
# 27             0             0               1               1           0
# 28             0             0               1               1           0
# 29             0             0               2               1           0
# 30             0             0               1               1           0
# 31         10520             0               2               1           1
# 32             0          2339               2               1           0
# 33             0             0               0               1           0
# 34         15024             0               2               1           1
# 35             0             0               0               1           0
# 36             0             0               1               1           1
# 37             0             0               2               1           0
# 38             0             0               1               1           0
# 39             0             0               1               1           0
# 40             0             0               1               1           0
# 41             0             0               1               2           0
# 42             0             0               2               1           0
# 43             0             0               1               1           0
# 44             0             0               2               1           1
# 45             0             0               1               1           1
# 46             0             0               2               1           1
# 47             0             0               0               1           0
# 48             0             0               2               1           0
# 49             0             0               2               1           1

# %%
train_Sel=train_data.drop(['fnlwgt','education'],axis=1)

#查看各特征与标签的相关性
corrDf=pd.DataFrame()
corrDf=train_Sel.corr()
corrDf['exceeds50K'].sort_values(ascending=True)
# Out:
# native-country    0.023777
# capital-loss      0.151032
# sex               0.218607
# capital-gain      0.226486
# age               0.237521
# hours-per-week    0.258875
# education-num     0.363979
# exceeds50K        1.000000
# Name: exceeds50K, dtype: float64

# %%
plt.figure(figsize=(8,8))
sns.heatmap(train_Sel[['exceeds50K','capital-loss','capital-gain','age','hours-per-week','education-num','sex','native-country']].corr(),cmap='BrBG',annot=True,
           linewidths=.5)
plt.xticks(rotation=45)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  [Text(0.5, 0, 'exceeds50K'),
#   Text(1.5, 0, 'capital-loss'),
#   Text(2.5, 0, 'capital-gain'),
#   Text(3.5, 0, 'age'),
#   Text(4.5, 0, 'hours-per-week'),
#   Text(5.5, 0, 'education-num'),
#   Text(6.5, 0, 'sex'),
#   Text(7.5, 0, 'native-country')])

# %%
train_Sel=pd.get_dummies(train_Sel)

# %%
#归一化
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()  # 也可以用标准化类，然后调用方法
train_Sel[['age','education-num','hours-per-week','capital-gain','capital-loss']] = min_max_scaler.fit_transform(train_Sel[['age','education-num','hours-per-week','capital-gain','capital-loss']])

# %%
train_Sel
# Out:
# array([[0.17808219, 0.28571429, 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.5890411 , 0.57142857, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.47945205, 0.28571429, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.45205479, 0.42857143, 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.10958904, 0.28571429, 0.        , ..., 0.        , 0.        ,
#         0.        ],
#        [0.54794521, 0.57142857, 1.        , ..., 0.        , 0.        ,
#         0.        ]])

# %%
y=train_Sel['exceeds50K']
x=train_Sel.drop('exceeds50K',axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-0b18e2d86ab5> in <module>
# ----> 1 y=train_Sel['exceeds50K']
#       2 x=train_Sel.drop('exceeds50K',axis=1)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24421 entries, 0 to 24420
# Data columns (total 44 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   age                                    24421 non-null  int64
#  1   education-num                          24421 non-null  int64
#  2   sex                                    24421 non-null  int64
#  3   capital-gain                           24421 non-null  int64
#  4   capital-loss                           24421 non-null  int64
#  5   hours-per-week                         24421 non-null  int64
#  6   native-country                         24421 non-null  int64
#  7   workclass_ Federal-gov                 24421 non-null  uint8
#  8   workclass_ Local-gov                   24421 non-null  uint8
#  9   workclass_ Never-worked                24421 non-null  uint8
#  10  workclass_ Private                     24421 non-null  uint8
#  11  workclass_ Self-emp-inc                24421 non-null  uint8
#  12  workclass_ Self-emp-not-inc            24421 non-null  uint8
#  13  workclass_ State-gov                   24421 non-null  uint8
#  14  workclass_ Without-pay                 24421 non-null  uint8
#  15  workclass_Unknown                      24421 non-null  uint8
#  16  marital-status_ Divorced               24421 non-null  uint8
#  17  marital-status_ Married-AF-spouse      24421 non-null  uint8
#  18  marital-status_ Married-civ-spouse     24421 non-null  uint8
#  19  marital-status_ Married-spouse-absent  24421 non-null  uint8
#  20  marital-status_ Never-married          24421 non-null  uint8
#  21  marital-status_ Separated              24421 non-null  uint8
#  22  marital-status_ Widowed                24421 non-null  uint8
#  23  occupation_ Adm-clerical               24421 non-null  uint8
#  24  occupation_ Armed-Forces               24421 non-null  uint8
#  25  occupation_ Craft-repair               24421 non-null  uint8
#  26  occupation_ Exec-managerial            24421 non-null  uint8
#  27  occupation_ Farming-fishing            24421 non-null  uint8
#  28  occupation_ Handlers-cleaners          24421 non-null  uint8
#  29  occupation_ Machine-op-inspct          24421 non-null  uint8
#  30  occupation_ Other-service              24421 non-null  uint8
#  31  occupation_ Priv-house-serv            24421 non-null  uint8
#  32  occupation_ Prof-specialty             24421 non-null  uint8
#  33  occupation_ Protective-serv            24421 non-null  uint8
#  34  occupation_ Sales                      24421 non-null  uint8
#  35  occupation_ Tech-support               24421 non-null  uint8
#  36  occupation_ Transport-moving           24421 non-null  uint8
#  37  occupation_Unknown                     24421 non-null  uint8
#  38  relationship_ Husband                  24421 non-null  uint8
#  39  relationship_ Not-in-family            24421 non-null  uint8
#  40  relationship_ Other-relative           24421 non-null  uint8
#  41  relationship_ Own-child                24421 non-null  uint8
#  42  relationship_ Unmarried                24421 non-null  uint8
#  43  relationship_ Wife                     24421 non-null  uint8
# dtypes: int64(7), uint8(37)
# memory usage: 2.2 MB

# %%
#导入机器学习算法库
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV,cross_val_score,StratifiedKFold

#设置kfold，交叉采样法拆分数据集
kfold=StratifiedKFold(n_splits=10)

#汇总不同模型算法
classifiers=[]
classifiers.append(SVC())
classifiers.append(DecisionTreeClassifier())
classifiers.append(RandomForestClassifier())
classifiers.append(ExtraTreesClassifier())
classifiers.append(GradientBoostingClassifier())
classifiers.append(KNeighborsClassifier())
classifiers.append(LogisticRegression())
classifiers.append(LinearDiscriminantAnalysis())

#不同机器学习交叉验证结果汇总
cv_results=[]
for classifier in classifiers:
    cv_results.append(cross_val_score(classifier,x,y,
                                      scoring='accuracy',cv=kfold,n_jobs=-1))

#求出模型得分的均值和标准差
cv_means=[]
cv_std=[]
for cv_result in cv_results:
    cv_means.append(cv_result.mean())
    cv_std.append(cv_result.std())
    
#汇总数据
cvResDf=pd.DataFrame({'cv_mean':cv_means,
                     'cv_std':cv_std,
                     'algorithm':['SVC','DecisionTreeCla','RandomForestCla','ExtraTreesCla',
                                  'GradientBoostingCla','KNN','LR','LinearDiscrimiAna']})

# %%
cvResDf
# Out:
#     cv_mean    cv_std            algorithm
# 0  0.802875  0.005079                  SVC
# 1  0.828672  0.005318      DecisionTreeCla
# 2  0.844069  0.008643      RandomForestCla
# 3  0.827935  0.008525        ExtraTreesCla
# 4  0.866099  0.004642  GradientBoostingCla
# 5  0.856271  0.006532                  KNN
# 6  0.848737  0.005064                   LR
# 7  0.841858  0.003951    LinearDiscrimiAna

# %%
cvResFacet=sns.FacetGrid(cvResDf.sort_values(by='cv_mean',ascending=False),sharex=False,
            sharey=False,aspect=2)
cvResFacet.map(sns.barplot,'cv_mean','algorithm',**{'xerr':cv_std},
               palette='muted')
cvResFacet.set(xlim=(0.7,0.9))
cvResFacet.add_legend()
# Out:
# /Users/zachary-sun/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
#GradientBoostingClassifier模型
GBC = GradientBoostingClassifier()
gb_param_grid = {'loss' : ["deviance"],
              'n_estimators' : [100,200,300],
              'learning_rate': [0.1, 0.05, 0.01],
              'max_depth': [4, 8],
              'min_samples_leaf': [100,150],
              'max_features': [0.3, 0.1] 
              }
modelgsGBC = GridSearchCV(GBC,param_grid = gb_param_grid, cv=kfold, 
                                     scoring="accuracy", n_jobs= -1, verbose = 1)
modelgsGBC.fit(x,y)
# Out:
# Fitting 10 folds for each of 72 candidates, totalling 720 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done 720 out of 720 | elapsed:  6.8min finished
# GridSearchCV(cv=StratifiedKFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=GradientBoostingClassifier(), n_jobs=-1,
#              param_grid={'learning_rate': [0.1, 0.05, 0.01],
#                          'loss': ['deviance'], 'max_depth': [4, 8],
#                          'max_features': [0.3, 0.1],
#                          'min_samples_leaf': [100, 150],
#                          'n_estimators': [100, 200, 300]},
#              scoring='accuracy', verbose=1)

# %%
#modelgsGBC模型
print('modelgsGBC模型得分为：%.3f'%modelgsGBC.best_score_)
# Out:
# modelgsGBC模型得分为：0.874

# %%
#testdata


test =  pd.read_csv("test.csv")
#替换缺失值"？"为NA
test.replace(' ?', NA, inplace = True)
#返回有nan的列
test.isna().any()
#替换NAN的值为Unknown
test['workclass'].replace(NA, 'Unknown', inplace = True)
test['occupation'].replace(NA, 'Unknown', inplace = True)
test['native-country'].replace(NA, 'Unknown', inplace = True)


#国家数据重分类,分为发达国家和发展中国家（不要运行2次）
#由于美国人最多，所以将国家缺失值填补为US
test['native-country'].replace(' United-States', 'US', inplace = True)
test['native-country'].replace('Unknown', 'US', inplace = True)
country = test['native-country']
country_type = country.unique()
for native_country in country_type:
    if native_country in [' United States',' United Kingdom',' Germany',' France',' Japan',' Italy',' Canada',' Russia']:
        test['native-country'].replace(native_country, 'Developed_country', inplace = True)
    else:
        test['native-country'].replace(native_country, 'Uneveloped_country', inplace = True)




#     if native_country != ' United-States' and native_country != 'Unknown':
#         train_data['native-country'].replace(native_country, 'Non_US', inplace = True)


#按学历，将1为没上过学，2-8为没上过大学，9为高中文凭，10为大学未毕业（可视为高中），11-12为专科，因此，应该重分类
def education(education_num):
    if education_num == 1:
        return 0
    elif (education_num > 1) & (education_num < 9):
        return 1
    elif (education_num >= 9) & (education_num < 11):
        return 2
    elif (education_num >= 11) & (education_num < 13):
        return 3
    else:
        return (education_num-9)
test['education-num'] = test['education-num'].map(education)

#只能运行一次
#将每周工作时长分为三段，一段为小于每周40小时，一段为每周40小时，一段为每周大于40小时
def workhours(hours_per_week):
    if hours_per_week < 40:
        return 0
    elif hours_per_week == 40:
        return 1
    else:
        return 2
test['hours-per-week'] = test['hours-per-week'].map(workhours)

#性别编码
encoder1 = OrdinalEncoder(cols = ['sex']).fit(test,test.iloc[:,-1]) # 转换sex为 female为1 和 male为2
test = encoder1.transform(test)
#国家编码
encoder2 = OrdinalEncoder(cols = ['native-country']).fit(test,test.iloc[:,-1]) # 转换sex为 female为1 和 male为2
test = encoder2.transform(test)

test_Sel=test.drop(['fnlwgt','education'],axis=1)
test_Sel=pd.get_dummies(test_Sel)
# Out:
# /Users/zachary-sun/anaconda3/lib/python3.8/site-packages/category_encoders/utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):

# %%
test_Sel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24421 entries, 0 to 24420
# Data columns (total 44 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   age                                    24421 non-null  int64
#  1   education-num                          24421 non-null  int64
#  2   sex                                    24421 non-null  int64
#  3   capital-gain                           24421 non-null  int64
#  4   capital-loss                           24421 non-null  int64
#  5   hours-per-week                         24421 non-null  int64
#  6   native-country                         24421 non-null  int64
#  7   workclass_ Federal-gov                 24421 non-null  uint8
#  8   workclass_ Local-gov                   24421 non-null  uint8
#  9   workclass_ Never-worked                24421 non-null  uint8
#  10  workclass_ Private                     24421 non-null  uint8
#  11  workclass_ Self-emp-inc                24421 non-null  uint8
#  12  workclass_ Self-emp-not-inc            24421 non-null  uint8
#  13  workclass_ State-gov                   24421 non-null  uint8
#  14  workclass_ Without-pay                 24421 non-null  uint8
#  15  workclass_Unknown                      24421 non-null  uint8
#  16  marital-status_ Divorced               24421 non-null  uint8
#  17  marital-status_ Married-AF-spouse      24421 non-null  uint8
#  18  marital-status_ Married-civ-spouse     24421 non-null  uint8
#  19  marital-status_ Married-spouse-absent  24421 non-null  uint8
#  20  marital-status_ Never-married          24421 non-null  uint8
#  21  marital-status_ Separated              24421 non-null  uint8
#  22  marital-status_ Widowed                24421 non-null  uint8
#  23  occupation_ Adm-clerical               24421 non-null  uint8
#  24  occupation_ Armed-Forces               24421 non-null  uint8
#  25  occupation_ Craft-repair               24421 non-null  uint8
#  26  occupation_ Exec-managerial            24421 non-null  uint8
#  27  occupation_ Farming-fishing            24421 non-null  uint8
#  28  occupation_ Handlers-cleaners          24421 non-null  uint8
#  29  occupation_ Machine-op-inspct          24421 non-null  uint8
#  30  occupation_ Other-service              24421 non-null  uint8
#  31  occupation_ Priv-house-serv            24421 non-null  uint8
#  32  occupation_ Prof-specialty             24421 non-null  uint8
#  33  occupation_ Protective-serv            24421 non-null  uint8
#  34  occupation_ Sales                      24421 non-null  uint8
#  35  occupation_ Tech-support               24421 non-null  uint8
#  36  occupation_ Transport-moving           24421 non-null  uint8
#  37  occupation_Unknown                     24421 non-null  uint8
#  38  relationship_ Husband                  24421 non-null  uint8
#  39  relationship_ Not-in-family            24421 non-null  uint8
#  40  relationship_ Other-relative           24421 non-null  uint8
#  41  relationship_ Own-child                24421 non-null  uint8
#  42  relationship_ Unmarried                24421 non-null  uint8
#  43  relationship_ Wife                     24421 non-null  uint8
# dtypes: int64(7), uint8(37)
# memory usage: 2.2 MB

# %%
GBCpreData_y=modelgsGBC.predict(test_Sel)
GBCpreData_y=GBCpreData_y.astype(int)
ID=np.array(range(1,24422))
GBCpreResultDf=pd.DataFrame()
GBCpreResultDf['id']=ID
GBCpreResultDf['prediction']=GBCpreData_y

# %%
GBCpreResultDf.to_csv('GBSmodle.csv',index=False)

# %%
# pd.set_option('display.max_rows', None)

# %%
sns.catplot('relationship',col='marital-status',data=train_data,kind = 'count')

# %%
train_data['occupation'].value_counts()

# %%
(train_data.loc[(train_data['occupation'] == 'Unknown') &(train_data['hours-per-week'] == 0)])['exceeds50K'].value_counts()

# %%
train_data['workclass'].value_counts()

# %%
(train_data.loc[(train_data['workclass']== 'Unknown') &(train_data['occupation']== 'Unknown')])['workclass'].value_counts()

# %%
train_data[train_data['workclass']==' Never-worked'].replace('Unknown',' No-work',inplace = True)

# %%
train_data.loc[(train_data['workclass'] == ' Never-worked') &(train_data['occupation']== 'Unknown')]

# %%
train_data.loc[train_data['workclass'].isin([' Without-pay',' Never-worked'])]

# %%
train_data.loc[(train_data['workclass']== 'Unknown') & (train_data['age'] < 24) & (train_data['education-num']>=13)]
